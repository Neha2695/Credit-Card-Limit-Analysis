# %%
import pandas as pd
A=pd.read_csv("C:/Users/Neha/Downloads/PythonNotes/Credit.csv")

# %% [markdown]
# # Data Profiling

# %%
A.head()
# Out:
#    Unnamed: 0  ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0           1   1   14.891   3606     283      2   34         11    Male
# 1           2   2  106.025   6645     483      3   82         15  Female
# 2           3   3  104.593   7075     514      4   71         11    Male
# 3           4   4  148.924   9504     681      3   36         11  Female
# 4           5   5   55.882   4897     357      2   68         16    Male
#
#   Student Married  Ethnicity  Balance
# 0      No     Yes  Caucasian      333
# 1     Yes     Yes      Asian      903
# 2      No      No      Asian      580
# 3      No      No      Asian      964
# 4      No     Yes  Caucasian      331

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  400 non-null    int64
#  1   ID          400 non-null    int64
#  2   Income      400 non-null    float64
#  3   Limit       400 non-null    int64
#  4   Rating      400 non-null    int64
#  5   Cards       400 non-null    int64
#  6   Age         400 non-null    int64
#  7   Education   400 non-null    int64
#  8   Gender      400 non-null    object
#  9   Student     400 non-null    object
#  10  Married     400 non-null    object
#  11  Ethnicity   400 non-null    object
#  12  Balance     400 non-null    int64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 40.8+ KB

# %%
A.describe()
# Out:
#        Unnamed: 0          ID      Income         Limit      Rating  \
# count  400.000000  400.000000  400.000000    400.000000  400.000000
# mean   200.500000  200.500000   45.218885   4735.600000  354.940000
# std    115.614301  115.614301   35.244273   2308.198848  154.724143
# min      1.000000    1.000000   10.354000    855.000000   93.000000
# 25%    100.750000  100.750000   21.007250   3088.000000  247.250000
# 50%    200.500000  200.500000   33.115500   4622.500000  344.000000
# 75%    300.250000  300.250000   57.470750   5872.750000  437.250000
# max    400.000000  400.000000  186.634000  13913.000000  982.000000
#
#             Cards         Age   Education      Balance
# count  400.000000  400.000000  400.000000   400.000000
# mean     2.957500   55.667500   13.450000   520.015000
# std      1.371275   17.249807    3.125207   459.758877
# min      1.000000   23.000000    5.000000     0.000000
# 25%      2.000000   41.750000   11.000000    68.750000
# ...

# %%
A.tail(20)
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 380         381  381  115.123   7760     538      3   83         14  Female
# 381         382  382  101.788   8029     574      2   84         11    Male
# 382         383  383   24.824   5495     409      1   33          9    Male
# 383         384  384   14.292   3274     282      9   64          9    Male
# 384         385  385   20.088   1870     180      3   76         16    Male
# 385         386  386   26.400   5640     398      3   58         15  Female
# 386         387  387   19.253   3683     287      4   57         10    Male
# 387         388  388   16.529   1357     126      3   62          9    Male
# 388         389  389   37.878   6827     482      2   80         13  Female
# 389         390  390   83.948   7100     503      2   44         18    Male
# 390         391  391  135.118  10578     747      3   81         15  Female
# ...

# %%
A=A.drop(labels=['Unnamed: 0',"ID"],axis=1)

# %%
A.head(3)
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0   14.891   3606     283      2   34         11    Male      No     Yes
# 1  106.025   6645     483      3   82         15  Female     Yes     Yes
# 2  104.593   7075     514      4   71         11    Male      No      No
#
#    Ethnicity  Balance
# 0  Caucasian      333
# 1      Asian      903
# 2      Asian      580

# %%
A.shape
# Out:
# (400, 11)

# %%
A.columns
# Out:
# Index(['Income', 'Limit', 'Rating', 'Cards', 'Age', 'Education', 'Gender',
#        'Student', 'Married', 'Ethnicity', 'Balance'],
#       dtype='object')

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Missing Data treatement

# %%
A.isna().sum()
# Out:
# Income       0
# Limit        0
# Rating       0
# Cards        0
# Age          0
# Education    0
# Gender       0
# Student      0
# Married      0
# Ethnicity    0
# Balance      0
# dtype: int64

# %% [markdown]
# No data is missing here

# %%
cat=[]
con=[]
for i in A.columns:
    if(A[i].dtype=='object'):
        cat.append(i)
    else:
        con.append(i)

# %%
cat
# Out:
# ['Gender', 'Student', 'Married', 'Ethnicity']

# %%
con
# Out:
# ['Income', 'Limit', 'Rating', 'Cards', 'Age', 'Education', 'Balance']

# %% [markdown]
# # EDA

# %% [markdown]
# # Univariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # Distribution plot

# %%
for i in con:
    sb.distplot(A[i])
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # Histogram

# %%
for i in con:
    A[i].hist()
    plt.show()

# %% [markdown]
# # Countplot

# %%
for i in cat:
    sb.countplot(A[i])
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # Bar graph

# %%
for i in cat:
    A[i].value_counts().plot(kind='barh')
    plt.show()

# %% [markdown]
# # Pie plot

# %%
for i in cat:
    A[i].value_counts().plot(kind='pie')
    plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
for i in A.columns:
    if(A[i].dtypes == 'object'):
        sb.boxplot(A[i],A.Limit)#Boxplot between categorical and continuous columns
        plt.xlabel(i)
        plt.ylabel('Limit')
        plt.show()
    else:
        plt.scatter(A[i],A.Limit)# Scatter plot between continuous and continuous columns
        plt.xlabel('Limit')
        plt.ylabel(i)
        plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # Correlation analysis with LIMIT

# %%
A.corr()['Limit']
# Out:
# Income       0.792088
# Limit        1.000000
# Rating       0.996880
# Cards        0.010231
# Age          0.100888
# Education   -0.023549
# Balance      0.861697
# Name: Limit, dtype: float64

# %% [markdown]
# # Multivariate Analysis

# %%
sb.pairplot(A)

# %% [markdown]
# # Mulitple Linear Regression

# %%
Y=A[['Limit']]
X=A[['Rating',"Balance","Income"]]

# %%
#Divide data in training and testing
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=95)

# %% [markdown]
# # Training Error

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
model=lr.fit(xtrain,ytrain)
pred=model.predict(xtrain)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytrain,pred)
# Out:
# 150.61939082785534

# %% [markdown]
# # Testing Error

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
model=lr.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# 135.32890019984916

# %% [markdown]
# # Standardization

# %%
con.remove("Limit")
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
Q=pd.DataFrame(ss.fit_transform(A[con]))

# %%
Y=A[['Limit']]
X=Q.join(pd.get_dummies(A[cat]))

from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=95)

from sklearn.linear_model import LinearRegression
lr=LinearRegression()
model=lr.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# 101.76071159401602

# %% [markdown]
# # Handle Multicollinearity using Regularization

# %% [markdown]
# # Lasso (L-1 Regularization)

# %%
from sklearn.linear_model import Lasso
ls=Lasso()
model=ls.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# 101.87917270818896

# %%
tunning_grid=[]
q=0.998
for i in range(1,100,1):
    tunning_grid.append(q-0.001)
    q=q-0.001
q=0
for i in range(1,100,1):
    tunning_grid.append(q+0.001)
    q=q+0.001

# %%
from sklearn.model_selection import GridSearchCV
tp={'alpha':tunning_grid}
ls=Lasso()
cv=GridSearchCV(ls,tp,scoring="neg_mean_absolute_error",cv=3)
cvmodel=cv.fit(xtrain,ytrain)
cvmodel.best_params_
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202768.9094311623, tolerance: 106538.44010516434
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202941.1278473921, tolerance: 106538.44010516434
#   model = cd_fast.enet_coordinate_descent(
# {'alpha': 0.09900000000000007}

# %%
from sklearn.linear_model import Lasso
ls=Lasso(alpha=0.09900000000000007)
model=ls.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# 101.73281475041863

# %% [markdown]
# # Ridge regularization(L-2 Regularization)

# %%
from sklearn.linear_model import Ridge
rg=Ridge()
model=ls.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# 101.73281475041863

# %%
from sklearn.model_selection import GridSearchCV
tp={'alpha':tunning_grid}
rg=Ridge()
cv=GridSearchCV(rg,tp,scoring="neg_mean_absolute_error",cv=3)
cvmodel=cv.fit(xtrain,ytrain)
cvmodel.best_params_
# Out:
# {'alpha': 0.09900000000000007}

# %%
from sklearn.linear_model import Ridge
rg=Ridge(alpha=0.09900000000000007)
model=ls.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# 101.73281475041863

# %% [markdown]
# # Decision Tree Regressor

# %%
Y=A[['Limit']]
X=Q.join(pd.get_dummies(A[cat]))

from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor(random_state=20)
model=dtc.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# 220.6125

# %% [markdown]
# # Pruning
# pre-pruning

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor(random_state=20,min_samples_split=3)
model=dtc.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# 218.6375

# %% [markdown]
# # Tuning

# %%
from sklearn.model_selection import GridSearchCV
tp={'min_samples_split':range(2,20,1)}
dtc=DecisionTreeRegressor(random_state=20)
cv=GridSearchCV(dtc,tp,scoring="neg_mean_absolute_error",cv=3)
cvmodel=cv.fit(xtrain,ytrain)
cvmodel.best_params_
# Out:
# {'min_samples_split': 5}

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor(random_state=20,min_samples_split=5)
model=dtc.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# 226.68854166666665

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor(random_state=20,min_samples_leaf=3)
model=dtc.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# 190.08854166666666

# %% [markdown]
# # Tuning

# %%
from sklearn.model_selection import GridSearchCV
tp={'min_samples_leaf':range(2,20,1)}
dtc=DecisionTreeRegressor(random_state=20)
cv=GridSearchCV(dtc,tp,scoring="neg_mean_absolute_error",cv=3)
cvmodel=cv.fit(xtrain,ytrain)
cvmodel.best_params_
# Out:
# {'min_samples_leaf': 4}

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor(random_state=20,min_samples_leaf=4)
model=dtc.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# 194.54229166666664

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor(random_state=20,max_depth=3)
model=dtc.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# 356.1131173329687

# %%
from sklearn.model_selection import GridSearchCV
tp={'max_depth':range(2,20,1)}
dtc=DecisionTreeRegressor(random_state=20)
cv=GridSearchCV(dtc,tp,scoring="neg_mean_absolute_error",cv=3)
cvmodel=cv.fit(xtrain,ytrain)
cvmodel.best_params_
# Out:
# {'max_depth': 8}

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor(random_state=20,max_depth=8)
model=dtc.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# 208.45775908119657

# %% [markdown]
# So by decision tree regressor error is not improved

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(random_state=20,n_estimators=30)
model=rfr.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# <ipython-input-116-70485122a54e>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model=rfr.fit(xtrain,ytrain)
# 186.4125

# %% [markdown]
# # Pruning
# Pre-pruning

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(random_state=20,n_estimators=30,min_samples_split=3)
model=rfr.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# <ipython-input-117-0ca7c1c3918f>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model=rfr.fit(xtrain,ytrain)
# 174.21478373015876

# %% [markdown]
# # Tuning

# %%
from sklearn.model_selection import GridSearchCV
tp={'min_samples_split':range(2,20,1)}
rfr=RandomForestRegressor(random_state=20)
cv=GridSearchCV(dtc,tp,scoring="neg_mean_absolute_error",cv=3)
cvmodel=cv.fit(xtrain,ytrain)
cvmodel.best_params_
# Out:
# {'min_samples_split': 6}

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(random_state=20,n_estimators=30,min_samples_split=6)
model=rfr.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# <ipython-input-123-955ed491d443>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model=rfr.fit(xtrain,ytrain)
# 183.72881577103453

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(random_state=20,n_estimators=30,min_samples_leaf=3)
model=rfr.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# <ipython-input-124-8dba1075048b>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model=rfr.fit(xtrain,ytrain)
# 188.74763791763786

# %%
from sklearn.model_selection import GridSearchCV
tp={'min_samples_leaf':range(2,20,1)}
rfr=RandomForestRegressor(random_state=20)
cv=GridSearchCV(dtc,tp,scoring="neg_mean_absolute_error",cv=3)
cvmodel=cv.fit(xtrain,ytrain)
cvmodel.best_params_
# Out:
# {'min_samples_leaf': 4}

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(random_state=20,n_estimators=30,min_samples_leaf=4)
model=rfr.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# <ipython-input-126-ebd5f167e098>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model=rfr.fit(xtrain,ytrain)
# 196.25196599642172

# %% [markdown]
# Post-pruning

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(random_state=20,n_estimators=30,max_depth=3)
model=rfr.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# <ipython-input-127-6ea9501ead72>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model=rfr.fit(xtrain,ytrain)
# 240.80687869219264

# %%
from sklearn.model_selection import GridSearchCV
tp={'max_depth':range(2,20,1)}
rfr=RandomForestRegressor(random_state=20)
cv=GridSearchCV(dtc,tp,scoring="neg_mean_absolute_error",cv=3)
cvmodel=cv.fit(xtrain,ytrain)
cvmodel.best_params_
# Out:
# {'max_depth': 8}

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(random_state=20,n_estimators=30,max_depth=8)
model=rfr.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# <ipython-input-131-8a4cf3173652>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model=rfr.fit(xtrain,ytrain)
# 175.80826956444972

# %% [markdown]
#  Error is not improved by random forest

# %% [markdown]
# # Adaptive Boosting

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
abc=AdaBoostRegressor(DecisionTreeRegressor(max_depth=2),n_estimators=10)
model=abc.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 492.3840989908231

# %% [markdown]
# # KNN(K-nearest-neighbors)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=6)
model = knn.fit(xtrain,ytrain)
pred = model.predict(xtest)
from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
# Out:
# 572.2145833333334

# %% [markdown]
# So least error we have got here is 101.73 by Ridge and Lasso regularization.So this is the best model
